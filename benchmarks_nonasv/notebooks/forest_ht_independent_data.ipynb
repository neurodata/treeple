# %% [markdown]
# # Test on Independent High-dimensional Data

# %%
from collections import defaultdict

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from scipy.special import expit

from sktree import RandomForestClassifier, RandomForestRegressor
from sktree.stats import (
    FeatureImportanceForestClassifier,
    FeatureImportanceForestRegressor,
    PermutationForestRegressor,
)

seed = 12345

# %%
# %load_ext autoreload
# %autoreload 2

# %%
rng = np.random.default_rng(seed)

# %%
n_samples = 600
n_features = 500

n_estimators = 125
n_jobs = -1
max_features = "sqrt"
test_size = 1.0 / 6
metric = "mse"
n_repeats = 500
permute_per_tree = False
sample_dataset_per_tree = False

# %% [markdown]
# # Run Pvalue Computation Over Many Instances

# %%
permute_per_tree = True
sample_dataset_per_tree = True


# initialize hypothesis tester
est = FeatureImportanceForestClassifier(
    RandomForestClassifier(
        max_features=1.0,
        # random_state=seed,
        n_estimators=n_estimators,
        n_jobs=-1,
    ),
    test_size=test_size,
    permute_per_tree=permute_per_tree,
    sample_dataset_per_tree=sample_dataset_per_tree,
)

# %%
stats = []
pvalues = []

for idx in range(500):
    X = rng.standard_normal(size=(n_samples, n_features))
    y = rng.binomial(1, 0.5, size=n_samples)  # .reshape(-1, 1)
    stat, pvalue = est.test(X, y, covariate_index=[0], metric="mi")
    est.reset()

    stats.append(stat)
    pvalues.append(pvalue)

# %%
plt.plot(pvalues)

# %%
permute_per_tree = False
sample_dataset_per_tree = False

# initialize hypothesis tester
est = FeatureImportanceForestClassifier(
    RandomForestClassifier(
        max_features=1.0,
        n_estimators=n_estimators,
        n_jobs=-1,
    ),
    test_size=test_size,
    permute_per_tree=permute_per_tree,
    sample_dataset_per_tree=sample_dataset_per_tree,
)

# %%
stats = []
pvalues = []

for idx in range(500):
    X = rng.standard_normal(size=(n_samples, n_features))
    y = rng.binomial(1, 0.5, size=n_samples)  # .reshape(-1, 1)
    stat, pvalue = est.test(X, y, covariate_index=[0], metric="mi")
    est.reset()

    stats.append(stat)
    pvalues.append(pvalue)

# %%
plt.plot(pvalues, "x")

# %%
permute_per_tree = True
sample_dataset_per_tree = False

rng = np.random.default_rng(seed)

# initialize hypothesis tester
est = FeatureImportanceForestClassifier(
    RandomForestClassifier(
        max_features=1.0,
        # random_state=seed,
        n_estimators=n_estimators,
        n_jobs=-1,
    ),
    # random_state=seed,
    test_size=test_size,
    permute_per_tree=permute_per_tree,
    sample_dataset_per_tree=sample_dataset_per_tree,
)

# %%
stats = []
pvalues = []

for idx in range(500):
    X = rng.standard_normal(size=(n_samples, n_features))
    y = rng.binomial(1, 0.5, size=n_samples)  # .reshape(-1, 1)
    stat, pvalue = est.test(X, y, covariate_index=[0], metric="mi")
    est.reset()

    stats.append(stat)
    pvalues.append(pvalue)

# %%
plt.plot(pvalues, "x")

# %%
permute_per_tree = False
sample_dataset_per_tree = True

rng = np.random.default_rng(seed)

# initialize hypothesis tester
est = FeatureImportanceForestClassifier(
    RandomForestClassifier(
        max_features=1.0,
        # random_state=seed,
        n_estimators=n_estimators,
        n_jobs=-1,
    ),
    # random_state=seed,
    test_size=test_size,
    permute_per_tree=permute_per_tree,
    sample_dataset_per_tree=sample_dataset_per_tree,
)

# %%
stats = []
pvalues = []

for idx in range(500):
    X = rng.standard_normal(size=(n_samples, n_features))
    y = rng.binomial(1, 0.5, size=n_samples)  # .reshape(-1, 1)
    stat, pvalue = est.test(X, y, covariate_index=[0], metric="mi")
    est.reset()

    stats.append(stat)
    pvalues.append(pvalue)
# Out:
# ---------------------------------------------------------------------------
# Empty                                     Traceback (most recent call last)
# File ~/miniforge3/envs/sktree/lib/python3.9/site-packages/joblib/parallel.py:1423, in Parallel.dispatch_one_batch(self, iterator)
#    1422 try:
# -> 1423     tasks = self._ready_batches.get(block=False)
#    1424 except queue.Empty:
#    1425     # slice the iterator n_jobs * batchsize items at a time. If the
#    1426     # slice returns less than that, then the current batchsize puts
#    (...)
#    1429     # accordingly to distribute evenly the last items between all
#    1430     # workers.
#
# File ~/miniforge3/envs/sktree/lib/python3.9/queue.py:168, in Queue.get(self, block, timeout)
#     167     if not self._qsize():
# --> 168         raise Empty
#     169 elif timeout is None:
#
# Empty:
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 7
#       5 X = rng.standard_normal(size=(n_samples, n_features))
#       6 y = rng.binomial(1, 0.5, size=n_samples)  # .reshape(-1, 1)
# ----> 7 stat, pvalue = est.test(X, y, covariate_index=[0], metric="mi")
#       8 est.reset()
#      10 stats.append(stat)
#
# File ~/Documents/scikit-tree/sktree/stats/forestht.py:450, in BaseForestHT.test(self, X, y, covariate_index, metric, n_repeats, return_posteriors, **metric_kwargs)
#     446 X, y, covariate_index = self._check_input(X, y, covariate_index)
#     448 if not self._is_fitted:
#     449     # first compute the test statistic on the un-permuted data
# --> 450     observe_stat, observe_posteriors, observe_samples = self.statistic(
#     451         X,
#     452         y,
#     453         covariate_index=None,
#     454         metric=metric,
#     455         return_posteriors=return_posteriors,
#     456         check_input=False,
#     457         **metric_kwargs,
#     458     )
#     459 else:
#     460     observe_samples = self.observe_samples_
#
# File ~/Documents/scikit-tree/sktree/stats/forestht.py:390, in BaseForestHT.statistic(self, X, y, covariate_index, metric, return_posteriors, check_input, **metric_kwargs)
#     387 if estimator.n_outputs_ > 1 and metric == "auc":
#     388     raise ValueError("AUC metric is not supported for multi-output")
# --> 390 return self._statistic(
#     391     estimator,
#     392     X,
#     393     y,
#     394     covariate_index=covariate_index,
#     395     metric=metric,
#     396     return_posteriors=return_posteriors,
#     397     **metric_kwargs,
#     398 )
#
# File ~/Documents/scikit-tree/sktree/stats/forestht.py:928, in FeatureImportanceForestClassifier._statistic(self, estimator, X, y, covariate_index, metric, return_posteriors, **metric_kwargs)
#     925 # both sampling dataset per tree or permuting per tree requires us to bypass the
#     926 # sklearn API to fit each tree individually
#     927 if self.sample_dataset_per_tree or self.permute_per_tree:
# --> 928     Parallel(n_jobs=estimator.n_jobs, verbose=self.verbose, prefer="threads")(
#     929         delayed(_parallel_build_trees_and_compute_posteriors)(
#     930             estimator,
#     931             idx,
#     932             indices_train,
#     933             indices_test,
#     934             X,
#     935             y,
#     936             covariate_index,
#     937             posterior_arr,
#     938             predict_posteriors,
#     939             self.permute_per_tree,
#     940             self._type_of_target_,
#     941         )
#     942         for idx, (indices_train, indices_test) in enumerate(self._get_estimators_indices(sample_separate=True))
#     943     )
#     944 else:
#     945     # fitting a forest will only get one unique train/test split
#     946     indices_train, indices_test = self.train_test_samples_[0]
#
# File ~/miniforge3/envs/sktree/lib/python3.9/site-packages/joblib/parallel.py:1950, in Parallel.__call__(self, iterable)
#    1944 self._call_ref = weakref.ref(output)
#    1946 # The first item from the output is blank, but it makes the interpreter
#    1947 # progress until it enters the Try/Except block of the generator and
#    1948 # reach the first `yield` statement. This starts the aynchronous
#    1949 # dispatch of the tasks to the workers.
# -> 1950 next(output)
#    1952 return output if self.return_generator else list(output)
#
# File ~/miniforge3/envs/sktree/lib/python3.9/site-packages/joblib/parallel.py:1588, in Parallel._get_outputs(self, iterator, pre_dispatch)
#    1586 detach_generator_exit = False
#    1587 try:
# -> 1588     self._start(iterator, pre_dispatch)
#    1589     # first yield returns None, for internal use only. This ensures
#    1590     # that we enter the try/except block and start dispatching the
#    1591     # tasks.
#    1592     yield
#
# File ~/miniforge3/envs/sktree/lib/python3.9/site-packages/joblib/parallel.py:1571, in Parallel._start(self, iterator, pre_dispatch)
#    1562 def _start(self, iterator, pre_dispatch):
#    1563     # Only set self._iterating to True if at least a batch
#    1564     # was dispatched. In particular this covers the edge
#    (...)
#    1568     # was very quick and its callback already dispatched all the
#    1569     # remaining jobs.
#    1570     self._iterating = False
# -> 1571     if self.dispatch_one_batch(iterator):
#    1572         self._iterating = self._original_iterator is not None
#    1574     while self.dispatch_one_batch(iterator):
#
# File ~/miniforge3/envs/sktree/lib/python3.9/site-packages/joblib/parallel.py:1434, in Parallel.dispatch_one_batch(self, iterator)
#    1431 n_jobs = self._cached_effective_n_jobs
#    1432 big_batch_size = batch_size * n_jobs
# -> 1434 islice = list(itertools.islice(iterator, big_batch_size))
#    1435 if len(islice) == 0:
#    1436     return False
#
# File ~/Documents/scikit-tree/sktree/stats/forestht.py:928, in <genexpr>(.0)
#     925 # both sampling dataset per tree or permuting per tree requires us to bypass the
#     926 # sklearn API to fit each tree individually
#     927 if self.sample_dataset_per_tree or self.permute_per_tree:
# --> 928     Parallel(n_jobs=estimator.n_jobs, verbose=self.verbose, prefer="threads")(
#     929         delayed(_parallel_build_trees_and_compute_posteriors)(
#     930             estimator,
#     931             idx,
#     932             indices_train,
#     933             indices_test,
#     934             X,
#     935             y,
#     936             covariate_index,
#     937             posterior_arr,
#     938             predict_posteriors,
#     939             self.permute_per_tree,
#     940             self._type_of_target_,
#     941         )
#     942         for idx, (indices_train, indices_test) in enumerate(self._get_estimators_indices(sample_separate=True))
#     943     )
#     944 else:
#     945     # fitting a forest will only get one unique train/test split
#     946     indices_train, indices_test = self.train_test_samples_[0]
#
# File ~/Documents/scikit-tree/sktree/stats/forestht.py:181, in BaseForestHT._get_estimators_indices(self, sample_separate)
#     178 seeds = self._seeds
#     180 if sample_separate:
# --> 181     if self._perm_seeds is None:
#     182         new_rng = np.random.default_rng(np.random.uniform(0, 1e6))
#     183         self._perm_seeds = new_rng.integers(low=0, high=np.iinfo(np.int32).max, size=len(self.estimator_.estimators_))
#
# AttributeError: 'FeatureImportanceForestClassifier' object has no attribute '_perm_seeds'

# %%
plt.plot(pvalues, "x")

# %%
print("done")

# %%
print("done")
