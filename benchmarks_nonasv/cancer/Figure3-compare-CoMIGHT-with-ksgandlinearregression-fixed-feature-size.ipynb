# %% [markdown]
# # A comparison of CoMIGHT against KSG and Linear Regression Based Estimates of Conditional Independence
#
# CoMIGHT is a fully non-parametric method for i) estimating CMI and ii) providing a pvalue indicating the statistical significance of the estimated CMI compared to the null hypothesis where the CMI is 0 (for a given dimensionality and sample size using permutation principles).
#
# Another nonparametric method for CMI is the kNN based KSG estimator, which also can be used along a permutation test to obtain a pvalue.
#
# Finally, a parametric method for CMI is the linear regression method, which computes partial correlation among variables under the assumption that the data arises from Gaussian distributions.

# %% [markdown]
# # TODO:
#
# 1. Sample size fix to 256
# 2. Dimensionality of X2 vary from 4 to 4096 (2^2 - 2^12)

# %%
import math
from collections import defaultdict

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from scipy.special import expit
from sklearn.datasets import (
    make_blobs,
    make_classification,
    make_sparse_spd_matrix,
    make_spd_matrix,
)
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.neighbors import KNeighborsClassifier

from sktree import HonestForestClassifier, RandomForestClassifier, RandomForestRegressor
from sktree.datasets.multiview import make_gaussian_mixture, make_joint_factor_model
from sktree.stats import (
    FeatureImportanceForestClassifier,
    FeatureImportanceForestRegressor,
    PermutationForestRegressor,
    PermutationTest,
)
from sktree.tree import DecisionTreeClassifier, MultiViewDecisionTreeClassifier

seed = 12345
rng = np.random.default_rng(seed)

# %%
import warnings

warnings.filterwarnings("ignore")

# %% [markdown]
# # Define Dataset Generators
#
# 1. Confounder: Y <- X1 -> X2
# 2. Collider: X1 -> Y <- X2
# 3. Independence: X1 -> Y  X2 (here we use `make_classification` from sklearn and add random noise)
# 4. Mediator: X1 -> X2 -> Y
# 5. Direct & Indirect Effects: X1 -> X2 -> Y; X1 -> Y

# %%
def make_confounder(n_samples, n_features, noise_dims, class_probs, seed):
    rng = np.random.default_rng(seed)

    fixed_center = rng.standard_normal(size=(n_features,))
    centers = [fixed_center, fixed_center]

    covariances = [
        make_spd_matrix(n_dim=n_features, random_state=seed),
        make_spd_matrix(n_dim=n_features, random_state=seed + 123),
    ]

    Xs, y = make_gaussian_mixture(
        centers,
        covariances,
        n_samples=n_samples,
        noise=1.0,
        noise_dims=noise_dims,
        shuffle=True,
        class_probs=class_probs,
        random_state=seed + idx,
    )

    signal_X = np.hstack((Xs[1], Xs[0]))

    return signal_X, y

# %%
def make_direct_indirect_effects(
    n_samples, n_features, n_features_2, noise_dims, class_probs, seed, flip_y=0.02
):
    rng = np.random.default_rng(seed)

    joint_covariance = make_spd_matrix(n_dim=n_features_2, random_state=seed + 123)
    full_covariances = [
        make_spd_matrix(n_dim=n_features_2, random_state=seed),
        joint_covariance,
    ]

    fixed_center = rng.standard_normal(size=(n_features_2,))
    full_centers = [fixed_center, fixed_center]

    # make joint factor model for class 0
    Xs_list = []
    classes = []
    for idx in range(2):
        if idx == 1:
            noise_dims = (noise_dims + n_features) - n_features_2
            n_features = n_features_2

        centers = [x[:n_features] for x in full_centers]
        covariances = [x[:n_features, :n_features] for x in full_covariances]

        Xs, _ = make_gaussian_mixture(
            centers,
            covariances,
            n_samples=math.ceil(n_samples // 2),
            noise=2.0,
            noise_dims=noise_dims,
            transform="sin",
            shuffle=True,
            class_probs=class_probs,
            add_latent_noise=True,
            random_state=seed + idx,
        )
        signal_X = np.hstack((Xs[0], Xs[1]))

        if idx == 0:
            signal_X = signal_X + rng.standard_normal(size=signal_X.shape)
        # print(signal_X.shape)
        Xs_list.append(signal_X)
        classes.append(np.ones((n_samples // 2, 1)) * idx)

    y = np.vstack(classes)
    # print([x.shape for x in Xs])
    # print([x.shape for x in Xs_list])
    X = np.vstack(Xs_list)
    # X = X + rng.standard_normal(size=X.shape)

    # Randomly replace labels
    if flip_y >= 0.0:
        flip_mask = rng.uniform(size=n_samples) < flip_y
        y[flip_mask] = rng.integers(0, 2, size=(flip_mask.sum(), 1))

    return X, y

# %%
def make_collider(n_samples, n_features, noise_dims, seed):
    rng = np.random.default_rng(seed)
    n_samples = n_samples * 2
    signal_X_1, y1 = make_classification(
        n_samples=n_samples,
        n_features=n_features + noise_dims,
        n_informative=n_features,
        n_redundant=10,
        n_repeated=0,
        n_classes=2,
        class_sep=1.0,
        flip_y=0.02,
        shuffle=False,
        random_state=seed,
    )
    signal_X_2, y2 = make_classification(
        n_samples=n_samples,
        n_features=n_features + noise_dims,
        n_informative=n_features,
        n_redundant=10,
        n_repeated=0,
        n_classes=2,
        class_sep=0.75,
        flip_y=0.02,
        shuffle=False,
        random_state=seed + 1,
    )
    signal_X = np.hstack((signal_X_1, signal_X_2))
    y = y1.copy()

    keep_inds = np.argwhere(y1 == y2)
    y = y[keep_inds, ...]
    y2 = y2[keep_inds, ...].squeeze()
    signal_X = signal_X[keep_inds, ...].squeeze()

    np.testing.assert_array_equal(y.squeeze(), y2)

    # Separate indices of 0s and 1s
    indices_0 = [i for i, val in enumerate(y) if val == 0]
    indices_1 = [i for i, val in enumerate(y) if val == 1]

    # Shuffle the indices
    rng.shuffle(indices_0)
    rng.shuffle(indices_1)

    # Select 250 random indices for 0s and 1s each
    selected_indices = indices_0[:250] + indices_1[:250]
    signal_X = signal_X[selected_indices, :].squeeze()
    y2 = y2[selected_indices, ...].squeeze()
    return signal_X, y2

# %%
def make_mediator(n_samples, n_features, noise_dims, n_views, joint_rank, seed):
    Xs, U, _ = make_joint_factor_model(
        n_views,
        n_features,
        n_samples=n_samples,
        joint_rank=joint_rank,
        noise_std=10.0,
        m=0.25,
        random_state=seed,
        return_decomp=True,
    )

    total_n_features = n_features * n_views + noise_dims

    signal_X = np.hstack(Xs)
    signal_X += rng.standard_normal(size=signal_X.shape)
    signal_X = np.hstack(
        (
            signal_X,
            rng.standard_normal(
                size=(n_samples, total_n_features - n_features * n_views)
            ),
        )
    )
    n_features_1 = signal_X.shape[1]

    y = rng.binomial(n=1, p=expit(signal_X[:, :n_features].sum(axis=1)), size=n_samples)

    # make signal view (i.e. X1) higher-dimensional
    U += rng.standard_normal(size=U.shape)  # * 2.0
    U = np.hstack(
        (
            U,
            rng.standard_normal(
                size=(signal_X.shape[0], total_n_features - joint_rank)
            ),
        )
    )

    # print(U.shape, signal_X.shape, y.shape, [x.shape for x in Xs])
    # first view is X1, which generates X2
    X = np.hstack((U, signal_X))

    return X, y

# %%
def make_direct_indirect_effects(n_samples, n_features, noise_dims, class_probs, seed):
    rng = np.random.default_rng(seed)

    # make joint factor model for class 0
    Xs_list = []
    classes = []
    for idx in range(2):
        fixed_center = rng.standard_normal(size=(n_features,))
        centers = [fixed_center, fixed_center]

        covariances = [
            make_spd_matrix(n_dim=n_features, random_state=seed + idx),
            make_spd_matrix(n_dim=n_features, random_state=seed + 123 + idx),
        ]

        Xs, _ = make_gaussian_mixture(
            centers,
            covariances,
            n_samples=math.ceil(n_samples // 2),
            noise=1.0,
            noise_dims=noise_dims,
            shuffle=True,
            class_probs=class_probs,
            random_state=seed + idx,
        )
        signal_X = np.hstack((Xs[1], Xs[0]))
        print(signal_X.shape)
        Xs_list.append(signal_X)
        classes.append(np.ones((n_samples // 2, 1)) * idx)

    y = np.vstack(classes)
    print([x.shape for x in Xs])
    X = np.vstack(Xs_list)

    return X, y

# %%
def generate_directindirect_dataset(
    n_samples,
    n_features,
    n_features_2,
    class_probs,
    test_size,
    max_fpr,
    n_repeats,
    seed,
):
    rng = np.random.default_rng(seed)
    for idx in range(n_repeats):
        n_features_begin = 0
        signal_X, y = make_direct_indirect_effects(
            n_samples=n_samples,
            n_features=n_features,
            n_features_2=n_features_2,
            noise_dims=noise_dims,
            class_probs=class_probs,
            seed=seed * idx,
        )
        n_features_ends = [n_features + noise_dims, None]

        _X = np.hstack(
            (
                signal_X,
                rng.standard_normal(
                    size=(n_samples, n_features_2_list[-1] - n_features - noise_dims)
                ),
            )
        )
        X = _X.copy()
        n_features_ends[1] = X.shape[1]
        print(X.shape, signal_X.shape, y.shape, n_features_ends)
        np.savez(f"./direct-indirect/direct-indirect_{idx}.npz", X=X, y=y)

# %%
X, y = make_mediator(500, 10, 80, 2, 5, seed)

# %%
print(X.shape, y.shape)
# Out:
# (500, 200) (500,)

# %% [markdown]
# # Run Computation
#
# Warning: For high n_repeats, this takes a long time.

# %%
# NOTE: increase this when running for full figure to 100
n_repeats = 5

# %%
class_probs = [0.5, 0.5]

# %%
# number of features in the first view
n_features = 10
noise_dims = 90

n_samples = 256
max_features = 0.3
n_jobs = -1
test_size = 0.2

max_fpr = 0.1

# number of features in the second view
pows = np.arange(2, 13, dtype=int)
n_features_2_list = [2**pow for pow in pows]
print(n_features_2_list)
# Out:
# [4, 8, 16, 32, 64, 128, 256, 512, 1024, 2048, 4096]

# %%
n_estimators = 500

# %% [markdown]
# ## Confounder Results

# %%
results = defaultdict(list)

for idx in range(n_repeats):
    n_features_begin = 0
    signal_X, y = make_confounder(
        n_samples=n_samples,
        n_features=n_features // 2,
        noise_dims=noise_dims // 2,
        class_probs=class_probs,
        seed=seed + idx,
    )
    n_features_ends = [n_features + noise_dims, None]
    print(signal_X.shape)
    assert False
    for n_features_2_ in n_features_2_list:
        _X = np.hstack((signal_X, rng.standard_normal(size=(n_samples, n_features_2_))))
        X = _X.copy()
        n_features_ends[1] = X.shape[1]

        print(X.shape, y.shape)
        print(n_features_ends)

        est = FeatureImportanceForestClassifier(
            estimator=HonestForestClassifier(
                n_estimators=n_estimators,
                max_features=max_features,
                tree_estimator=MultiViewDecisionTreeClassifier(
                    feature_set_ends=n_features_ends,
                    apply_max_features_per_feature_set=True,
                ),
                random_state=seed,
                honest_fraction=0.5,
                n_jobs=n_jobs,
            ),
            random_state=seed,
            test_size=test_size,
            sample_dataset_per_tree=False,
        )

        # compute the statistic
        # also compute the pvalue when shuffling X1
        covariate_index = np.arange(0, n_features_ends[0])
        stat, pvalue = est.test(
            X, y, covariate_index=covariate_index, metric="auc", max_fpr=max_fpr
        )
        results["mvrf_pvalue_x1"].append(pvalue)
        # get the actual partial-AUC of the unpermuted dataset for the forest
        stat = est.observe_stat_
        results["mvrf_pauc"].append(stat)

        # now compute the same relevant quantities using kNN
        neigh = KNeighborsClassifier(n_neighbors=int(np.sqrt(X.shape[1])) + 1)
        # compute pvalue for kNN based job
        permest = PermutationTest(
            neigh, n_repeats=100, random_state=seed + idx + n_features_2_
        )
        pauc, pvalue = permest.test(
            X, y, covariate_index=covariate_index, metric="auc", max_fpr=max_fpr
        )

        results["knn_pauc"].append(pauc)
        results["knn_pvalue_x1"].append(pvalue)

        # also compute the relevant quantities using linear regression
        lr = LogisticRegression(random_state=seed + idx + n_features_2_)
        permest = PermutationTest(
            lr, n_repeats=100, random_state=seed + idx + n_features_2_
        )
        pauc, pvalue = permest.test(
            X, y, covariate_index=covariate_index, metric="auc", max_fpr=max_fpr
        )
        results["lr_pvalue_x1"].append(pvalue)
        results["lr_pauc"].append(pauc)

        # now compute the pvalue when shuffling X2
        covariate_index = np.arange(n_features_ends[0], n_features_ends[1])
        _, pvalue = est.test(
            X, y, covariate_index=covariate_index, metric="auc", max_fpr=max_fpr
        )
        results["mvrf_pvalue_x2"].append(pvalue)

        # now compute the same relevant quantities using kNN
        # compute pvalue for kNN based job
        permest = PermutationTest(
            neigh, n_repeats=100, random_state=seed + idx + n_features_2_
        )
        _, pvalue = permest.test(
            X, y, covariate_index=covariate_index, metric="auc", max_fpr=max_fpr
        )
        results["knn_pvalue_x2"].append(pvalue)

        # also compute the relevant quantities using linear regression
        permest = PermutationTest(
            lr, n_repeats=100, random_state=seed + idx + n_features_2_
        )
        _, pvalue = permest.test(
            X, y, covariate_index=covariate_index, metric="auc", max_fpr=max_fpr
        )
        results["lr_pvalue_x2"].append(pvalue)

        results["n_samples"].append(n_samples)
        results["n_features_2"].append(n_features_2_)
        results["noise_dims"].append(noise_dims)
# Out:
# (256, 100)
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[16], line 14
#      12 n_features_ends = [n_features + noise_dims, None]
#      13 print(signal_X.shape)
# ---> 14 assert False
#      15 for n_features_2_ in n_features_2_list:
#      16     _X = np.hstack((signal_X, rng.standard_normal(size=(n_samples, n_features_2_))))
#
# AssertionError:

# %%
df = pd.DataFrame(results)

# save the results
df.to_csv("./cv_comight_mv_vs_knn_vs_lr_confounder_model.csv")

print(df.columns)
print(df.shape)
# Out:
# Index(['mvrf_pvalue_x1', 'mvrf_pauc', 'knn_pauc', 'knn_pvalue_x1',
#        'lr_pvalue_x1', 'lr_pauc', 'mvrf_pvalue_x2', 'knn_pvalue_x2',
#        'lr_pvalue_x2', 'n_samples', 'n_features_2', 'noise_dims'],
#       dtype='object')
# (55, 12)

# %% [markdown]
# ## Collider Results

# %%
results = defaultdict(list)

for idx in range(n_repeats):
    n_features_begin = 0
    signal_X, y = make_collider(
        n_samples=n_samples,
        n_features=n_features,
        noise_dims=noise_dims,
        seed=seed + idx,
    )
    n_features_ends = [n_features + noise_dims, None]

    for n_features_2_ in n_features_2_list:
        _X = np.hstack((signal_X, rng.standard_normal(size=(n_samples, n_features_2_))))
        X = _X.copy()
        n_features_ends[1] = X.shape[1]

        print(X.shape, y.shape)
        print(n_features_ends)

        est = FeatureImportanceForestClassifier(
            estimator=HonestForestClassifier(
                n_estimators=n_estimators,
                max_features=max_features,
                tree_estimator=MultiViewDecisionTreeClassifier(
                    feature_set_ends=n_features_ends,
                    apply_max_features_per_feature_set=True,
                ),
                random_state=seed,
                honest_fraction=0.5,
                n_jobs=n_jobs,
            ),
            random_state=seed,
            test_size=test_size,
            sample_dataset_per_tree=False,
        )

        # compute the statistic
        # also compute the pvalue when shuffling X1
        covariate_index = np.arange(0, n_features_ends[0])
        stat, pvalue = est.test(
            X, y, covariate_index=covariate_index, metric="auc", max_fpr=max_fpr
        )
        results["mvrf_pvalue_x1"].append(pvalue)
        # get the actual partial-AUC of the unpermuted dataset for the forest
        stat = est.observe_stat_
        results["mvrf_pauc"].append(stat)

        # now compute the same relevant quantities using kNN
        neigh = KNeighborsClassifier(n_neighbors=int(np.sqrt(X.shape[1])) + 1)
        # compute pvalue for kNN based job
        permest = PermutationTest(
            neigh, n_repeats=100, random_state=seed + idx + n_features_2_
        )
        pauc, pvalue = permest.test(
            X, y, covariate_index=covariate_index, metric="auc", max_fpr=max_fpr
        )

        results["knn_pauc"].append(pauc)
        results["knn_pvalue_x1"].append(pvalue)

        # also compute the relevant quantities using linear regression
        lr = LogisticRegression(random_state=seed + idx + n_features_2_)
        permest = PermutationTest(
            lr, n_repeats=100, random_state=seed + idx + n_features_2_
        )
        pauc, pvalue = permest.test(
            X, y, covariate_index=covariate_index, metric="auc", max_fpr=max_fpr
        )
        results["lr_pvalue_x1"].append(pvalue)
        results["lr_pauc"].append(pauc)

        # now compute the pvalue when shuffling X2
        covariate_index = np.arange(n_features_ends[0], n_features_ends[1])
        _, pvalue = est.test(
            X, y, covariate_index=covariate_index, metric="auc", max_fpr=max_fpr
        )
        results["mvrf_pvalue_x2"].append(pvalue)

        # now compute the same relevant quantities using kNN
        # compute pvalue for kNN based job
        permest = PermutationTest(
            neigh, n_repeats=100, random_state=seed + idx + n_features_2_
        )
        _, pvalue = permest.test(
            X, y, covariate_index=covariate_index, metric="auc", max_fpr=max_fpr
        )
        results["knn_pvalue_x2"].append(pvalue)

        # also compute the relevant quantities using linear regression
        permest = PermutationTest(
            lr, n_repeats=100, random_state=seed + idx + n_features_2_
        )
        _, pvalue = permest.test(
            X, y, covariate_index=covariate_index, metric="auc", max_fpr=max_fpr
        )
        results["lr_pvalue_x2"].append(pvalue)

        results["n_samples"].append(n_samples)
        results["n_features_2"].append(n_features_2_)
        results["noise_dims"].append(noise_dims)
# Out:
# (500, 200) (500,)
# [100, 200]
# (500, 1000) (500,)
# [100, 1000]
# (500, 2000) (500,)
# [100, 2000]
# (500, 3000) (500,)
# [100, 3000]
# (500, 4000) (500,)
# [100, 4000]
# (500, 5000) (500,)
# [100, 5000]
# (500, 6000) (500,)
# [100, 6000]
# (500, 7000) (500,)
# [100, 7000]
# (500, 8000) (500,)
# [100, 8000]
# (500, 9000) (500,)
# [100, 9000]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[90], line 41
#      38 # compute the statistic
#      39 # also compute the pvalue when shuffling X1
#      40 covariate_index = np.arange(0, n_features_ends[0])
# ---> 41 stat, pvalue = est.test(
#      42     X, y, covariate_index=covariate_index, metric="auc", max_fpr=max_fpr
#      43 )
#      44 results["mvrf_pvalue_x1"].append(pvalue)
#      45 # get the actual partial-AUC of the unpermuted dataset for the forest
#
# File ~/Documents/scikit-tree/sktree/stats/forestht.py:544, in BaseForestHT.test(self, X, y, covariate_index, metric, n_repeats, return_posteriors, **metric_kwargs)
#     541     covariate_index = np.arange(X.shape[1], dtype=int)
#     543 # next permute the data
# --> 544 permute_stat, permute_posteriors, permute_samples = self.statistic(
#     545     X,
#     546     y,
#     547     covariate_index=covariate_index,
#     548     metric=metric,
#     549     return_posteriors=return_posteriors,
#     550     check_input=False,
#     551     **metric_kwargs,
#     552 )
#     553 self.permute_stat_ = permute_stat
#     555 # Note: at this point, both `estimator` and `permuted_estimator_` should
#     556 # have been fitted already, so we can now compute on the null by resampling
#     557 # the posteriors and computing the test statistic on the resampled posteriors
#
# File ~/Documents/scikit-tree/sktree/stats/forestht.py:464, in BaseForestHT.statistic(self, X, y, covariate_index, metric, return_posteriors, check_input, **metric_kwargs)
#     461 if estimator.n_outputs_ > 1 and metric == "auc":
#     462     raise ValueError("AUC metric is not supported for multi-output")
# --> 464 return self._statistic(
#     465     estimator,
#     466     X,
#     467     y,
#     468     covariate_index=covariate_index,
#     469     metric=metric,
#     470     return_posteriors=return_posteriors,
#     471     **metric_kwargs,
#     472 )
#
# File ~/Documents/scikit-tree/sktree/stats/forestht.py:1112, in FeatureImportanceForestClassifier._statistic(self, estimator, X, y, covariate_index, metric, return_posteriors, **metric_kwargs)
#    1110     if self._type_of_target_ == "binary" or (y.ndim > 1 and y.shape[1] == 1):
#    1111         y_train = y_train.ravel()
# -> 1112     estimator.fit(X_train, y_train)
#    1114 # list of tree outputs. Each tree output is (n_samples, n_outputs), or (n_samples,)
#    1115 if predict_posteriors:
#    1116     # all_proba = Parallel(n_jobs=estimator.n_jobs, verbose=self.verbose)(
#    1117     #     delayed(_parallel_predict_proba)(
#    (...)
#    1122
#    1123     # TODO: probably a more elegant way of doing this
#
# File ~/miniforge3/envs/sktree/lib/python3.9/site-packages/sklearn/base.py:1152, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1145     estimator._validate_params()
#    1147 with config_context(
#    1148     skip_parameter_validation=(
#    1149         prefer_skip_nested_validation or global_skip_validation
#    1150     )
#    1151 ):
# -> 1152     return fit_method(estimator, *args, **kwargs)
#
# File ~/Documents/scikit-tree/sktree/ensemble/_honest_forest.py:412, in HonestForestClassifier.fit(self, X, y, sample_weight, classes)
#     382 """
#     383 Build a forest of trees from the training set (X, y).
#     384
#    (...)
#     409     Fitted tree estimator.
#     410 """
#     411 X, y = check_X_y(X, y, multi_output=True)
# --> 412 super().fit(X, y, sample_weight=sample_weight, classes=classes)
#     414 # Compute honest decision function
#     415 self.honest_decision_function_ = self._predict_proba(
#     416     X, indices=self.honest_indices_, impute_missing=np.nan
#     417 )
#
# File ~/miniforge3/envs/sktree/lib/python3.9/site-packages/sklearn/base.py:1152, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1145     estimator._validate_params()
#    1147 with config_context(
#    1148     skip_parameter_validation=(
#    1149         prefer_skip_nested_validation or global_skip_validation
#    1150     )
#    1151 ):
# -> 1152     return fit_method(estimator, *args, **kwargs)
#
# File ~/Documents/scikit-tree/sktree/_lib/./sklearn/ensemble/_forest.py:596, in BaseForest.fit(self, X, y, sample_weight, classes)
#     585 trees = [
#     586     self._make_estimator(append=False, random_state=random_state)
#     587     for i in range(n_more_estimators)
#     588 ]
#     590 # Parallel loop: we prefer the threading backend as the Cython code
#     591 # for fitting the trees is internally releasing the Python GIL
#     592 # making threading more efficient than multiprocessing in
#     593 # that case. However, for joblib 0.12+ we respect any
#     594 # parallel_backend contexts set at a higher level,
#     595 # since correctness does not rely on using threads.
# --> 596 trees = Parallel(
#     597     n_jobs=self.n_jobs,
#     598     verbose=self.verbose,
#     599     prefer="threads",
#     600 )(
#     601     delayed(_parallel_build_trees)(
#     602         t,
#     603         self.bootstrap,
#     604         X,
#     605         y,
#     606         sample_weight,
#     607         i,
#     608         len(trees),
#     609         verbose=self.verbose,
#     610         class_weight=self.class_weight,
#     611         n_samples_bootstrap=n_samples_bootstrap,
#     612         missing_values_in_feature_mask=missing_values_in_feature_mask,
#     613         classes=classes,
#     614     )
#     615     for i, t in enumerate(trees)
#     616 )
#     618 # Collect newly grown trees
#     619 self.estimators_.extend(trees)
#
# File ~/miniforge3/envs/sktree/lib/python3.9/site-packages/sklearn/utils/parallel.py:65, in Parallel.__call__(self, iterable)
#      60 config = get_config()
#      61 iterable_with_config = (
#      62     (_with_config(delayed_func, config), args, kwargs)
#      63     for delayed_func, args, kwargs in iterable
#      64 )
# ---> 65 return super().__call__(iterable_with_config)
#
# File ~/miniforge3/envs/sktree/lib/python3.9/site-packages/joblib/parallel.py:1952, in Parallel.__call__(self, iterable)
#    1946 # The first item from the output is blank, but it makes the interpreter
#    1947 # progress until it enters the Try/Except block of the generator and
#    1948 # reach the first `yield` statement. This starts the aynchronous
#    1949 # dispatch of the tasks to the workers.
#    1950 next(output)
# -> 1952 return output if self.return_generator else list(output)
#
# File ~/miniforge3/envs/sktree/lib/python3.9/site-packages/joblib/parallel.py:1595, in Parallel._get_outputs(self, iterator, pre_dispatch)
#    1592     yield
#    1594     with self._backend.retrieval_context():
# -> 1595         yield from self._retrieve()
#    1597 except GeneratorExit:
#    1598     # The generator has been garbage collected before being fully
#    1599     # consumed. This aborts the remaining tasks if possible and warn
#    1600     # the user if necessary.
#    1601     self._exception = True
#
# File ~/miniforge3/envs/sktree/lib/python3.9/site-packages/joblib/parallel.py:1713, in Parallel._retrieve(self)
#    1708     continue
#    1710 # We need to be careful: the job list can be filling up as
#    1711 # we empty it and Python list are not thread-safe by
#    1712 # default hence the use of the lock
# -> 1713 with self._lock:
#    1714     batched_results = self._jobs.popleft()
#    1716 # Flatten the batched results to output one output at a time
#
# KeyboardInterrupt:

# %%
df = pd.DataFrame(results)

# save the results
df.to_csv("./cv_comight_mv_vs_knn_vs_lr_collider_model.csv")

print(df.columns)
print(df.shape)

# %% [markdown]
# ## Mediator Results

# %%
n_features = 5
noise_dims = 90
n_views = 2

# %%
results = defaultdict(list)

for idx in range(n_repeats):
    n_features_begin = 0
    signal_X, y = make_mediator(
        n_samples=n_samples,
        n_features=n_features,
        noise_dims=noise_dims,
        n_views=n_views,
        joint_rank=5,
        seed=seed + idx,
    )
    n_features_ends = [n_views * n_features + noise_dims, None]

    for n_features_2_ in n_features_2_list:
        _X = np.hstack((signal_X, rng.standard_normal(size=(n_samples, n_features_2_))))
        X = _X.copy()
        n_features_ends[1] = X.shape[1]

        print(X.shape, y.shape)
        print(n_features_ends)

        est = FeatureImportanceForestClassifier(
            estimator=HonestForestClassifier(
                n_estimators=n_estimators,
                max_features=max_features,
                tree_estimator=MultiViewDecisionTreeClassifier(
                    feature_set_ends=n_features_ends,
                    apply_max_features_per_feature_set=True,
                ),
                random_state=seed,
                honest_fraction=0.5,
                n_jobs=n_jobs,
            ),
            random_state=seed,
            test_size=test_size,
            sample_dataset_per_tree=False,
        )

        # compute the statistic
        # also compute the pvalue when shuffling X1
        covariate_index = np.arange(0, n_features_ends[0])
        stat, pvalue = est.test(
            X, y, covariate_index=covariate_index, metric="auc", max_fpr=max_fpr
        )
        results["mvrf_pvalue_x1"].append(pvalue)
        # get the actual partial-AUC of the unpermuted dataset for the forest
        stat = est.observe_stat_
        results["mvrf_pauc"].append(stat)

        # now compute the same relevant quantities using kNN
        neigh = KNeighborsClassifier(n_neighbors=int(np.sqrt(X.shape[1])) + 1)
        # compute pvalue for kNN based job
        permest = PermutationTest(
            neigh, n_repeats=100, random_state=seed + idx + n_features_2_
        )
        pauc, pvalue = permest.test(
            X, y, covariate_index=covariate_index, metric="auc", max_fpr=max_fpr
        )

        results["knn_pauc"].append(pauc)
        results["knn_pvalue_x1"].append(pvalue)

        # also compute the relevant quantities using linear regression
        lr = LogisticRegression(random_state=seed + idx + n_features_2_)
        permest = PermutationTest(
            lr, n_repeats=100, random_state=seed + idx + n_features_2_
        )
        pauc, pvalue = permest.test(
            X, y, covariate_index=covariate_index, metric="auc", max_fpr=max_fpr
        )
        results["lr_pvalue_x1"].append(pvalue)
        results["lr_pauc"].append(pauc)

        # now compute the pvalue when shuffling X2
        covariate_index = np.arange(n_features_ends[0], n_features_ends[1])
        _, pvalue = est.test(
            X, y, covariate_index=covariate_index, metric="auc", max_fpr=max_fpr
        )
        results["mvrf_pvalue_x2"].append(pvalue)

        # now compute the same relevant quantities using kNN
        # compute pvalue for kNN based job
        permest = PermutationTest(
            neigh, n_repeats=100, random_state=seed + idx + n_features_2_
        )
        _, pvalue = permest.test(
            X, y, covariate_index=covariate_index, metric="auc", max_fpr=max_fpr
        )
        results["knn_pvalue_x2"].append(pvalue)

        # also compute the relevant quantities using linear regression
        permest = PermutationTest(
            lr, n_repeats=100, random_state=seed + idx + n_features_2_
        )
        _, pvalue = permest.test(
            X, y, covariate_index=covariate_index, metric="auc", max_fpr=max_fpr
        )
        results["lr_pvalue_x2"].append(pvalue)

        results["n_samples"].append(n_samples)
        results["n_features_2"].append(n_features_2_)
        results["noise_dims"].append(noise_dims)
# Out:
# (500, 200) (500,)
# [100, 200]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 43
#      40 # compute the statistic
#      41 # also compute the pvalue when shuffling X1
#      42 covariate_index = np.arange(0, n_features_ends[0])
# ---> 43 stat, pvalue = est.test(
#      44     X, y, covariate_index=covariate_index, metric="auc", max_fpr=max_fpr
#      45 )
#      46 results["mvrf_pvalue_x1"].append(pvalue)
#      47 # get the actual partial-AUC of the unpermuted dataset for the forest
#
# File ~/miniforge3/envs/sktree/lib/python3.9/site-packages/sktree/stats/forestht.py:526, in BaseForestHT.test(self, X, y, covariate_index, metric, n_repeats, return_posteriors, **metric_kwargs)
#     522 X, y, covariate_index = self._check_input(X, y, covariate_index)
#     524 if not self._is_fitted:
#     525     # first compute the test statistic on the un-permuted data
# --> 526     observe_stat, observe_posteriors, observe_samples = self.statistic(
#     527         X,
#     528         y,
#     529         covariate_index=None,
#     530         metric=metric,
#     531         return_posteriors=return_posteriors,
#     532         check_input=False,
#     533         **metric_kwargs,
#     534     )
#     535 else:
#     536     observe_samples = self.observe_samples_
#
# File ~/miniforge3/envs/sktree/lib/python3.9/site-packages/sktree/stats/forestht.py:464, in BaseForestHT.statistic(self, X, y, covariate_index, metric, return_posteriors, check_input, **metric_kwargs)
#     461 if estimator.n_outputs_ > 1 and metric == "auc":
#     462     raise ValueError("AUC metric is not supported for multi-output")
# --> 464 return self._statistic(
#     465     estimator,
#     466     X,
#     467     y,
#     468     covariate_index=covariate_index,
#     469     metric=metric,
#     470     return_posteriors=return_posteriors,
#     471     **metric_kwargs,
#     472 )
#
# File ~/miniforge3/envs/sktree/lib/python3.9/site-packages/sktree/stats/forestht.py:1112, in FeatureImportanceForestClassifier._statistic(self, estimator, X, y, covariate_index, metric, return_posteriors, **metric_kwargs)
#    1110     if self._type_of_target_ == "binary" or (y.ndim > 1 and y.shape[1] == 1):
#    1111         y_train = y_train.ravel()
# -> 1112     estimator.fit(X_train, y_train)
#    1114 # list of tree outputs. Each tree output is (n_samples, n_outputs), or (n_samples,)
#    1115 if predict_posteriors:
#    1116     # all_proba = Parallel(n_jobs=estimator.n_jobs, verbose=self.verbose)(
#    1117     #     delayed(_parallel_predict_proba)(
#    (...)
#    1122
#    1123     # TODO: probably a more elegant way of doing this
#
# File ~/miniforge3/envs/sktree/lib/python3.9/site-packages/sklearn/base.py:1152, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1145     estimator._validate_params()
#    1147 with config_context(
#    1148     skip_parameter_validation=(
#    1149         prefer_skip_nested_validation or global_skip_validation
#    1150     )
#    1151 ):
# -> 1152     return fit_method(estimator, *args, **kwargs)
#
# File ~/miniforge3/envs/sktree/lib/python3.9/site-packages/sktree/ensemble/_honest_forest.py:412, in HonestForestClassifier.fit(self, X, y, sample_weight, classes)
#     382 """
#     383 Build a forest of trees from the training set (X, y).
#     384
#    (...)
#     409     Fitted tree estimator.
#     410 """
#     411 X, y = check_X_y(X, y, multi_output=True)
# --> 412 super().fit(X, y, sample_weight=sample_weight, classes=classes)
#     414 # Compute honest decision function
#     415 self.honest_decision_function_ = self._predict_proba(
#     416     X, indices=self.honest_indices_, impute_missing=np.nan
#     417 )
#
# File ~/miniforge3/envs/sktree/lib/python3.9/site-packages/sklearn/base.py:1152, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1145     estimator._validate_params()
#    1147 with config_context(
#    1148     skip_parameter_validation=(
#    1149         prefer_skip_nested_validation or global_skip_validation
#    1150     )
#    1151 ):
# -> 1152     return fit_method(estimator, *args, **kwargs)
#
# File ~/miniforge3/envs/sktree/lib/python3.9/site-packages/sktree/_lib/sklearn/ensemble/_forest.py:596, in BaseForest.fit(self, X, y, sample_weight, classes)
#     585 trees = [
#     586     self._make_estimator(append=False, random_state=random_state)
#     587     for i in range(n_more_estimators)
#     588 ]
#     590 # Parallel loop: we prefer the threading backend as the Cython code
#     591 # for fitting the trees is internally releasing the Python GIL
#     592 # making threading more efficient than multiprocessing in
#     593 # that case. However, for joblib 0.12+ we respect any
#     594 # parallel_backend contexts set at a higher level,
#     595 # since correctness does not rely on using threads.
# --> 596 trees = Parallel(
#     597     n_jobs=self.n_jobs,
#     598     verbose=self.verbose,
#     599     prefer="threads",
#     600 )(
#     601     delayed(_parallel_build_trees)(
#     602         t,
#     603         self.bootstrap,
#     604         X,
#     605         y,
#     606         sample_weight,
#     607         i,
#     608         len(trees),
#     609         verbose=self.verbose,
#     610         class_weight=self.class_weight,
#     611         n_samples_bootstrap=n_samples_bootstrap,
#     612         missing_values_in_feature_mask=missing_values_in_feature_mask,
#     613         classes=classes,
#     614     )
#     615     for i, t in enumerate(trees)
#     616 )
#     618 # Collect newly grown trees
#     619 self.estimators_.extend(trees)
#
# File ~/miniforge3/envs/sktree/lib/python3.9/site-packages/sklearn/utils/parallel.py:65, in Parallel.__call__(self, iterable)
#      60 config = get_config()
#      61 iterable_with_config = (
#      62     (_with_config(delayed_func, config), args, kwargs)
#      63     for delayed_func, args, kwargs in iterable
#      64 )
# ---> 65 return super().__call__(iterable_with_config)
#
# File ~/miniforge3/envs/sktree/lib/python3.9/site-packages/joblib/parallel.py:1952, in Parallel.__call__(self, iterable)
#    1946 # The first item from the output is blank, but it makes the interpreter
#    1947 # progress until it enters the Try/Except block of the generator and
#    1948 # reach the first `yield` statement. This starts the aynchronous
#    1949 # dispatch of the tasks to the workers.
#    1950 next(output)
# -> 1952 return output if self.return_generator else list(output)
#
# File ~/miniforge3/envs/sktree/lib/python3.9/site-packages/joblib/parallel.py:1595, in Parallel._get_outputs(self, iterator, pre_dispatch)
#    1592     yield
#    1594     with self._backend.retrieval_context():
# -> 1595         yield from self._retrieve()
#    1597 except GeneratorExit:
#    1598     # The generator has been garbage collected before being fully
#    1599     # consumed. This aborts the remaining tasks if possible and warn
#    1600     # the user if necessary.
#    1601     self._exception = True
#
# File ~/miniforge3/envs/sktree/lib/python3.9/site-packages/joblib/parallel.py:1707, in Parallel._retrieve(self)
#    1702 # If the next job is not ready for retrieval yet, we just wait for
#    1703 # async callbacks to progress.
#    1704 if ((len(self._jobs) == 0) or
#    1705     (self._jobs[0].get_status(
#    1706         timeout=self.timeout) == TASK_PENDING)):
# -> 1707     time.sleep(0.01)
#    1708     continue
#    1710 # We need to be careful: the job list can be filling up as
#    1711 # we empty it and Python list are not thread-safe by
#    1712 # default hence the use of the lock
#
# KeyboardInterrupt:

# %%
df = pd.DataFrame(results)

# save the results
df.to_csv("./cv_comight_mv_vs_knn_vs_lr_mediator_model.csv")

print(df.columns)
print(df.shape)

# %% [markdown]
# ## Direct/Indirect Effect Results

# %%
n_features = 10
noise_dims = 90

# %%
results = defaultdict(list)

for idx in range(n_repeats):
    n_features_begin = 0
    signal_X, y = make_direct_indirect_effects(
        n_samples=n_samples,
        n_features=n_features,
        noise_dims=noise_dims,
        class_probs=class_probs,
        seed=seed + idx,
    )
    n_features_ends = [n_features + noise_dims, None]

    for n_features_2_ in n_features_2_list:
        _X = np.hstack((signal_X, rng.standard_normal(size=(n_samples, n_features_2_))))
        X = _X.copy()
        n_features_ends[1] = X.shape[1]

        print(X.shape, y.shape)
        print(n_features_ends)

        est = FeatureImportanceForestClassifier(
            estimator=HonestForestClassifier(
                n_estimators=n_estimators,
                max_features=max_features,
                tree_estimator=MultiViewDecisionTreeClassifier(
                    feature_set_ends=n_features_ends,
                    apply_max_features_per_feature_set=True,
                ),
                random_state=seed,
                honest_fraction=0.5,
                n_jobs=n_jobs,
            ),
            random_state=seed,
            test_size=test_size,
            sample_dataset_per_tree=False,
        )

        # compute the statistic
        # also compute the pvalue when shuffling X1
        covariate_index = np.arange(0, n_features_ends[0])
        stat, pvalue = est.test(
            X, y, covariate_index=covariate_index, metric="auc", max_fpr=max_fpr
        )
        results["mvrf_pvalue_x1"].append(pvalue)
        # get the actual partial-AUC of the unpermuted dataset for the forest
        stat = est.observe_stat_
        results["mvrf_pauc"].append(stat)

        # now compute the same relevant quantities using kNN
        neigh = KNeighborsClassifier(n_neighbors=int(np.sqrt(X.shape[1])) + 1)
        # compute pvalue for kNN based job
        permest = PermutationTest(
            neigh, n_repeats=100, random_state=seed + idx + n_features_2_
        )
        pauc, pvalue = permest.test(
            X, y, covariate_index=covariate_index, metric="auc", max_fpr=max_fpr
        )

        results["knn_pauc"].append(pauc)
        results["knn_pvalue_x1"].append(pvalue)

        # also compute the relevant quantities using linear regression
        lr = LogisticRegression(random_state=seed + idx + n_features_2_)
        permest = PermutationTest(
            lr, n_repeats=100, random_state=seed + idx + n_features_2_
        )
        pauc, pvalue = permest.test(
            X, y, covariate_index=covariate_index, metric="auc", max_fpr=max_fpr
        )
        results["lr_pvalue_x1"].append(pvalue)
        results["lr_pauc"].append(pauc)

        # now compute the pvalue when shuffling X2
        covariate_index = np.arange(n_features_ends[0], n_features_ends[1])
        _, pvalue = est.test(
            X, y, covariate_index=covariate_index, metric="auc", max_fpr=max_fpr
        )
        results["mvrf_pvalue_x2"].append(pvalue)

        # now compute the same relevant quantities using kNN
        # compute pvalue for kNN based job
        permest = PermutationTest(
            neigh, n_repeats=100, random_state=seed + idx + n_features_2_
        )
        _, pvalue = permest.test(
            X, y, covariate_index=covariate_index, metric="auc", max_fpr=max_fpr
        )
        results["knn_pvalue_x2"].append(pvalue)

        # also compute the relevant quantities using linear regression
        permest = PermutationTest(
            lr, n_repeats=100, random_state=seed + idx + n_features_2_
        )
        _, pvalue = permest.test(
            X, y, covariate_index=covariate_index, metric="auc", max_fpr=max_fpr
        )
        results["lr_pvalue_x2"].append(pvalue)

        results["n_samples"].append(n_samples)
        results["n_features_2"].append(n_features_2_)
        results["noise_dims"].append(noise_dims)
# Out:
# (250, 200)
# (250, 200)
# [(250, 100), (250, 100)]
# (500, 200) (500, 1)
# [100, 200]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[22], line 56
#      52 # compute pvalue for kNN based job
#      53 permest = PermutationTest(
#      54     neigh, n_repeats=100, random_state=seed + idx + n_features_2_
#      55 )
# ---> 56 pauc, pvalue = permest.test(
#      57     X, y, covariate_index=covariate_index, metric="auc", max_fpr=max_fpr
#      58 )
#      60 results["knn_pauc"].append(pauc)
#      61 results["knn_pvalue_x1"].append(pvalue)
#
# File ~/miniforge3/envs/sktree/lib/python3.9/site-packages/sktree/stats/monte_carlo.py:116, in PermutationTest.test(self, X, y, covariate_index, metric, n_repeats, return_posteriors, **metric_kwargs)
#     112 self.observe_stat_ = pauc
#     114 # compute null distribution of the test statistic
#     115 # WARNING: this could take a long time, since it fits a new forest
# --> 116 null_dist = _compute_null_distribution_perm(
#     117     X_train=X[indices_train, :],
#     118     y_train=y[indices_train, :],
#     119     X_test=X[indices_test, :],
#     120     y_test=y[indices_test, :],
#     121     covariate_index=covariate_index,
#     122     est=self.estimator_,
#     123     metric=metric,
#     124     n_repeats=n_repeats,
#     125     seed=self.random_state,
#     126 )
#     128 if not return_posteriors:
#     129     self.null_dist_ = np.array(null_dist)
#
# File ~/miniforge3/envs/sktree/lib/python3.9/site-packages/sktree/stats/utils.py:162, in _compute_null_distribution_perm(X_train, y_train, X_test, y_test, covariate_index, est, metric, n_repeats, seed, **metric_kwargs)
#     159 # train a new forest on the permuted data
#     160 # XXX: should there be a train/test split here? even w/ honest forests?
#     161 est.fit(X_train, y_train.ravel())
# --> 162 y_pred = est.predict(X_test)
#     164 # compute two instances of the metric from the sampled trees
#     165 metric_val = metric_func(y_test, y_pred, **metric_kwargs)
#
# File ~/miniforge3/envs/sktree/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:254, in KNeighborsClassifier.predict(self, X)
#     250 if self.weights == "uniform":
#     251     if self._fit_method == "brute" and ArgKminClassMode.is_usable_for(
#     252         X, self._fit_X, self.metric
#     253     ):
# --> 254         probabilities = self.predict_proba(X)
#     255         if self.outputs_2d_:
#     256             return np.stack(
#     257                 [
#     258                     self.classes_[idx][np.argmax(probas, axis=1)]
#    (...)
#     261                 axis=1,
#     262             )
#
# File ~/miniforge3/envs/sktree/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:355, in KNeighborsClassifier.predict_proba(self, X)
#     351         return probabilities
#     353     # In that case, we do not need the distances to perform
#     354     # the weighting so we do not compute them.
# --> 355     neigh_ind = self.kneighbors(X, return_distance=False)
#     356     neigh_dist = None
#     357 else:
#
# File ~/miniforge3/envs/sktree/lib/python3.9/site-packages/sklearn/neighbors/_base.py:822, in KNeighborsMixin.kneighbors(self, X, n_neighbors, return_distance)
#     815 use_pairwise_distances_reductions = (
#     816     self._fit_method == "brute"
#     817     and ArgKmin.is_usable_for(
#     818         X if X is not None else self._fit_X, self._fit_X, self.effective_metric_
#     819     )
#     820 )
#     821 if use_pairwise_distances_reductions:
# --> 822     results = ArgKmin.compute(
#     823         X=X,
#     824         Y=self._fit_X,
#     825         k=n_neighbors,
#     826         metric=self.effective_metric_,
#     827         metric_kwargs=self.effective_metric_params_,
#     828         strategy="auto",
#     829         return_distance=return_distance,
#     830     )
#     832 elif (
#     833     self._fit_method == "brute" and self.metric == "precomputed" and issparse(X)
#     834 ):
#     835     results = _kneighbors_from_graph(
#     836         X, n_neighbors=n_neighbors, return_distance=return_distance
#     837     )
#
# File ~/miniforge3/envs/sktree/lib/python3.9/site-packages/sklearn/metrics/_pairwise_distances_reduction/_dispatcher.py:259, in ArgKmin.compute(cls, X, Y, k, metric, chunk_size, metric_kwargs, strategy, return_distance)
#     178 """Compute the argkmin reduction.
#     179
#     180 Parameters
#    (...)
#     256 returns.
#     257 """
#     258 if X.dtype == Y.dtype == np.float64:
# --> 259     return ArgKmin64.compute(
#     260         X=X,
#     261         Y=Y,
#     262         k=k,
#     263         metric=metric,
#     264         chunk_size=chunk_size,
#     265         metric_kwargs=metric_kwargs,
#     266         strategy=strategy,
#     267         return_distance=return_distance,
#     268     )
#     270 if X.dtype == Y.dtype == np.float32:
#     271     return ArgKmin32.compute(
#     272         X=X,
#     273         Y=Y,
#    (...)
#     279         return_distance=return_distance,
#     280     )
#
# File sklearn/metrics/_pairwise_distances_reduction/_argkmin.pyx:90, in sklearn.metrics._pairwise_distances_reduction._argkmin.ArgKmin64.compute()
#
# File ~/miniforge3/envs/sktree/lib/python3.9/site-packages/threadpoolctl.py:440, in _ThreadpoolLimiter.__exit__(self, type, value, traceback)
#     437 def __enter__(self):
#     438     return self
# --> 440 def __exit__(self, type, value, traceback):
#     441     self.restore_original_limits()
#     443 @classmethod
#     444 def wrap(cls, controller, *, limits=None, user_api=None):
#
# KeyboardInterrupt:

# %%
df = pd.DataFrame(results)

# save the results
df.to_csv("./cv_comight_mv_vs_knn_vs_lr_directindirecteffects_model.csv")

print(df.columns)
print(df.shape)

# %% [markdown]
# ## Independent View Results

# %%
n_features = 20
noise_dims = 80
n_samples = 500
max_features = 0.3
n_jobs = -1
test_size = 0.2

max_fpr = 0.1

n_features_2_list = np.linspace(900, 10_000 - 100, 10, dtype=int)
n_features_2_list = np.insert(n_features_2_list, 0, 100)
print(n_features_2_list)
# Out:
# [ 100  900 1900 2900 3900 4900 5900 6900 7900 8900 9900]

# %%
results = defaultdict(list)

for idx in range(n_repeats):
    n_features_begin = 0
    signal_X, y = make_classification(
        n_samples=n_samples,
        n_features=n_features + noise_dims,
        n_informative=n_features,
        random_state=seed + idx,
    )
    n_features_ends = [n_features + noise_dims, None]

    for n_features_2_ in n_features_2_list:
        _X = np.hstack((signal_X, rng.standard_normal(size=(n_samples, n_features_2_))))
        X = _X.copy()
        n_features_ends[1] = X.shape[1]

        print(X.shape, y.shape)
        print(n_features_ends)

        est = FeatureImportanceForestClassifier(
            estimator=HonestForestClassifier(
                n_estimators=n_estimators,
                max_features=max_features,
                tree_estimator=MultiViewDecisionTreeClassifier(
                    feature_set_ends=n_features_ends,
                    apply_max_features_per_feature_set=True,
                ),
                random_state=seed,
                honest_fraction=0.5,
                n_jobs=n_jobs,
            ),
            random_state=seed,
            test_size=test_size,
            sample_dataset_per_tree=False,
        )

        # compute the statistic
        # also compute the pvalue when shuffling X1
        covariate_index = np.arange(0, n_features_ends[0])
        stat, pvalue = est.test(
            X, y, covariate_index=covariate_index, metric="auc", max_fpr=max_fpr
        )
        results["mvrf_pvalue_x1"].append(pvalue)
        # get the actual partial-AUC of the unpermuted dataset for the forest
        stat = est.observe_stat_
        results["mvrf_pauc"].append(stat)

        # now compute the same relevant quantities using kNN
        neigh = KNeighborsClassifier(n_neighbors=int(np.sqrt(X.shape[1])) + 1)
        # compute pvalue for kNN based job
        permest = PermutationTest(
            neigh, n_repeats=100, random_state=seed + idx + n_features_2_
        )
        pauc, pvalue = permest.test(
            X, y, covariate_index=covariate_index, metric="auc", max_fpr=max_fpr
        )

        results["knn_pauc"].append(pauc)
        results["knn_pvalue_x1"].append(pvalue)

        # also compute the relevant quantities using linear regression
        lr = LogisticRegression(random_state=seed + idx + n_features_2_)
        permest = PermutationTest(
            lr, n_repeats=100, random_state=seed + idx + n_features_2_
        )
        pauc, pvalue = permest.test(
            X, y, covariate_index=covariate_index, metric="auc", max_fpr=max_fpr
        )
        results["lr_pvalue_x1"].append(pvalue)
        results["lr_pauc"].append(pauc)

        # now compute the pvalue when shuffling X2
        covariate_index = np.arange(n_features_ends[0], n_features_ends[1])
        _, pvalue = est.test(
            X, y, covariate_index=covariate_index, metric="auc", max_fpr=max_fpr
        )
        results["mvrf_pvalue_x2"].append(pvalue)

        # now compute the same relevant quantities using kNN
        # compute pvalue for kNN based job
        permest = PermutationTest(
            neigh, n_repeats=100, random_state=seed + idx + n_features_2_
        )
        _, pvalue = permest.test(
            X, y, covariate_index=covariate_index, metric="auc", max_fpr=max_fpr
        )
        results["knn_pvalue_x2"].append(pvalue)

        # also compute the relevant quantities using linear regression
        permest = PermutationTest(
            lr, n_repeats=100, random_state=seed + idx + n_features_2_
        )
        _, pvalue = permest.test(
            X, y, covariate_index=covariate_index, metric="auc", max_fpr=max_fpr
        )
        results["lr_pvalue_x2"].append(pvalue)

        results["n_samples"].append(n_samples)
        results["n_features_2"].append(n_features_2_)
        results["noise_dims"].append(noise_dims)
# Out:
# (500, 200) (500,)
# [100, 200]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[31], line 55
#      51 # compute pvalue for kNN based job
#      52 permest = PermutationTest(
#      53     neigh, n_repeats=100, random_state=seed + idx + n_features_2_
#      54 )
# ---> 55 pauc, pvalue = permest.test(
#      56     X, y, covariate_index=covariate_index, metric="auc", max_fpr=max_fpr
#      57 )
#      59 results["knn_pauc"].append(pauc)
#      60 results["knn_pvalue_x1"].append(pvalue)
#
# File ~/miniforge3/envs/sktree/lib/python3.9/site-packages/sktree/stats/monte_carlo.py:116, in PermutationTest.test(self, X, y, covariate_index, metric, n_repeats, return_posteriors, **metric_kwargs)
#     112 self.observe_stat_ = pauc
#     114 # compute null distribution of the test statistic
#     115 # WARNING: this could take a long time, since it fits a new forest
# --> 116 null_dist = _compute_null_distribution_perm(
#     117     X_train=X[indices_train, :],
#     118     y_train=y[indices_train, :],
#     119     X_test=X[indices_test, :],
#     120     y_test=y[indices_test, :],
#     121     covariate_index=covariate_index,
#     122     est=self.estimator_,
#     123     metric=metric,
#     124     n_repeats=n_repeats,
#     125     seed=self.random_state,
#     126 )
#     128 if not return_posteriors:
#     129     self.null_dist_ = np.array(null_dist)
#
# File ~/miniforge3/envs/sktree/lib/python3.9/site-packages/sktree/stats/utils.py:155, in _compute_null_distribution_perm(X_train, y_train, X_test, y_test, covariate_index, est, metric, n_repeats, seed, **metric_kwargs)
#     152 perm_X_cov = X_test[test_index_arr, covariate_index]
#     153 X_test[:, covariate_index] = perm_X_cov
# --> 155 rng.shuffle(train_index_arr)
#     156 perm_X_cov = X_train[train_index_arr, covariate_index]
#     157 X_train[:, covariate_index] = perm_X_cov
#
# KeyboardInterrupt:

# %%
df = pd.DataFrame(results)

# save the results
df.to_csv("./cv_comight_mv_vs_knn_vs_lr_independentview_model.csv")

print(df.columns)
print(df.shape)

# %% [markdown]
# # Plotting the Results

# %%
df = pd.read_csv(
    "./cv_comight_mv_vs_knn_vs_lr_confounder_model.csv", index_col=0, header=0
)

display(df.head())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df = pd.read_csv(
#       2     "./cv_comight_mv_vs_knn_vs_lr_confounder_model.csv", index_col=0, header=0
#       3 )
#       5 display(df.head())
#
# NameError: name 'pd' is not defined

# %%
# melt the dataframe, to make it easier to plot
df.drop(
    [
        "noise_dims",
        "lr_pauc",
        "knn_pauc",
        "mvrf_pauc",
        "mvrf_pvalue_x2",
        "lr_pvalue_x2",
        "knn_pvalue_x2",
        # "mvrf_pvalue_x1",
        # "lr_pvalue_x1",
        # "knn_pvalue_x1",
    ],
    inplace=True,
    axis=1,
)
df = pd.melt(
    df,
    id_vars=["n_features_2", "n_samples"],
    var_name="model",
    value_name="score",
)

# %%
fig, ax = plt.subplots()
sns.lineplot(data=df, x="n_features_2", y="score", marker="o", hue="model", ax=ax)
ax.set_ylabel("PValue")
ax.set_xlabel("Number of features in second view")
ax.set_title("Gaussian Mixture Model (with Transformation) (MVRF vs RF Coleman PValue)")
plt.show()

# %%
df = pd.DataFrame(np.concatenate((X, y[:, np.newaxis]), axis=1))
x_cols = np.array([f"x{idx}" for idx in range(X.shape[1])])
y_cols = np.array([f"y0"])
z_cols = x_cols[0:2]
df.columns = np.hstack((x_cols, y_cols))
print(df.columns)
# Out:
# Index(['x0', 'x1', 'x2', 'x3', 'x4', 'x5', 'x6', 'x7', 'x8', 'x9',
#        ...
#        'x191', 'x192', 'x193', 'x194', 'x195', 'x196', 'x197', 'x198', 'x199',
#        'y0'],
#       dtype='object', length=201)

# %% [markdown]
# # Compare partial-AUC performance
#
# - compare against kNN
# - compare against linear regression

# %% [markdown]
# # Power plots (3rd Row): Compare now the PValues when Shuffling X2
#
# Here are the structures that are expected to reject the null because X1 \not\perp Y | X2:
# 1. Confounder: Y <- X1 -> X2
# 2. Collider: X1 -> Y <- X2
# 3. Independence: X1 -> Y  X2 (here we use `make_classification` from sklearn and add random noise)
# 4. Direct & Indirect Effects: X1 -> X2 -> Y; X1 -> Y
#
# Here are the structures that are expected to fail to reject the null:
# 4. Mediator: X1 -> X2 -> Y
# 5. Completely independent views: X1  Y  X2

# %% [markdown]
# # (4th Row): Compare now the PValues when Shuffling X1
#
# Now, we can reverse the question and compare what happens and if we correctly (fail-to) reject the null hypotheses.
#
# Here are the structures that are expected to reject the null because X1 \not\perp Y | X2:
# 1. Confounder: Y <- X1 -> X2
# 2. Collider: X1 -> Y <- X2
# 3. Independence: X1 -> Y  X2 (here we use `make_classification` from sklearn and add random noise)
# 4. Direct & Indirect Effects: X1 -> X2 -> Y; X1 -> Y
#
# Here are the structures that are expected to fail to reject the null:
# 4. Mediator: X1 -> X2 -> Y
# 5. Completely independent views: X1  Y  X2
